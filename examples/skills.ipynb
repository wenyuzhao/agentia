# %% [markdown]
# # Use agent skills

# %%
from agentia import Agent
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
agent = Agent(
    model="openai/gpt-5-nano",
    skills=["."],  # Load all skills in the current directory
)

response = await agent.run("What is the weather and temperature like in boston?")

print(response.text)
# Out:
# The current weather in Boston is 27 degrees Celsius. The sky is clear and sunny.
